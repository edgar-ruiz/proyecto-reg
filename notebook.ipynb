# %% [markdown]
# # Presentación de los datos
#
# Usaremos una base de datos con información de algunas características de inmuebles en Estados Unidos llamada`USA_Housing`. Las columnas de la base de datos son:
#
# > * '`Avg. Area Income`': con el ingreso promedio de los residentes que viven en la ciudad donde se encuentra el inmueble.
# > * '`Avg. Area House Age`': la antigüedad promedio de las casas en la zona.
# > * '`Avg. Area Number of Rooms`': el promedio de cuartos de las casas de la zona.
# > * '`Avg. Area Number of Bedrooms`': el número de recámaras de las casas de la zona.
# > * '`Area Population`': el número de personas que residen en la ciudad donde se encuentra el inmueble.
# > * '`Price`': precio de venta.
# > * '`Address`': dirección del inmueble.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

sns.set_style("whitegrid")
plt.style.use("fivethirtyeight")

# %%
USAhousing = pd.read_csv('/kaggle/input/usa-housing/USA_Housing.csv')
USAhousing.head()

# %%
USAhousing.info()

# %%
USAhousing.describe()

# %%
USAhousing.columns

# %% [markdown]
# # Análisis exploratorio

# %%
sns.pairplot(USAhousing)

# %%
sns.distplot(USAhousing['Price'])

# %%
sns.heatmap(USAhousing.corr(), annot=True)

# %% [markdown]
# # 📈 Entrena y evalúa un modelo de regresión
